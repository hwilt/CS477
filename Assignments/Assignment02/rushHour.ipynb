# %%
# %load_ext autoreload
# %autoreload 2
from rush import *
import matplotlib.pyplot as plt
import numpy as np
import time

# %%
blocking_heuristic(0)
# Out:
# 0

# %%
s = State()
s.load_puzzle("jams/hard.txt")
s.plot()
print(s)
# Out:
#    -1   -1   -1   -1   -1   -1
#    -1   -1    2   -1   -1   -1
#     0    0    2   -1   -1   -1
#    -1   -1    2    3    3    5
#     1    1    1   -1    4    5
#    -1   -1   -1   -1    4    5

# %% [markdown]
# # Part 1: Breadth-First Tree Search

# %% [markdown]
# ### Goal Node (5 Points)

# %%
s = State()
s.load_puzzle("jams/1.txt")
s.plot()
print("Is Goal: ", s.is_goal())
# Out:
# Is Goal:  False

# %%
s = State()
s.load_puzzle("jams/Solved.txt")
s.plot()
print("Is Goal: ", s.is_goal())
# Out:
# Is Goal:  True

# %% [markdown]
# ### Neighboring States (10 Points)

# %%
s = State()
s.load_puzzle("jams/1.txt")
neighbors = s.get_neighbors()
# Plot everything
N = len(neighbors)+1
K = int(np.ceil(np.sqrt(N))) # Figure out a square grid to put these on

plt.figure(figsize=(10, 10))
plt.subplot(K, K, 1)
plt.title("Original")
s.plot()
for i, n in enumerate(neighbors):
    plt.subplot(K, K, i+2)
    n.plot()
    plt.title("Neighbor {}".format(i))
plt.tight_layout()

print("# of neighbors: {}".format(len(neighbors)))
# Out:
# # of neighbors: 7

# %% [markdown]
# ### Breadth-First Tree Search (15 Points)

# %% [markdown]
# **VERY** Easy Puzzle

# %%
s = State()
s.load_puzzle("jams/veryeasy.txt")

tic = time.time() # Time the solution
solution = s.solve()
toc = time.time()
print("Elapsed time: {:.3f} seconds".format(toc-tic))
for i, s in enumerate(solution):
    plt.figure()
    s.plot()
    plt.title("Step {}".format(i))
print(len(solution))
# Out:
# Elapsed time: 0.002 seconds
# 6

# %% [markdown]
# Easy Puzzle

# %%
s = State()
s.load_puzzle("jams/easy.txt")

tic = time.time() # Time the solution
solution = s.solve()
toc = time.time()
print("Elapsed time: {:.3f} seconds".format(toc-tic))
for i, s in enumerate(solution):
    plt.figure()
    s.plot()
    plt.title("Step {}".format(i))
print(len(solution))
# Out:
# Elapsed time: 7.749 seconds
# 10

# %% [markdown]
# # Part 2: Smarter Searching
#
# ### Breadth-First Graph Search (10 Points)

# %%
s = State()
s.load_puzzle("jams/easy.txt")

tic = time.time() # Time the solution
solution = s.solve_graph()
toc = time.time()
print("Elapsed time: {:.3f} seconds".format(toc-tic))
for i, s in enumerate(solution):
    plt.figure()
    s.plot()
    plt.title("Step {}".format(i))
print(len(solution))
# Out:
# Elapsed time: 0.003 seconds
# 10

# %% [markdown]
# ### A* Search (10 Points)

# %%
s = State()
s.load_puzzle("jams/5.txt")

s.plot()

print("blocking_heursitic: {}".format(blocking_heuristic(s)))
print("my_heuristic: {}".format(my_heuristic(s)))
# Out:
# blocking_heursitic: 2
# my_heuristic: 4

# %%
s = State()
s.load_puzzle("jams/2.txt")

solution, count = s.solve_graph()
print("number of BFS Optimal Steps: {}, count: {}".format(len(solution), count))
solution, count = s.solve_astar(blocking_heuristic)
print("number of a* Optimal Steps: {}, count: {}".format(len(solution), count))
# Out:
# number of BFS Optimal Steps: 15, count: 3267
# number of a* Optimal Steps: 15, count: 3268

# %% [markdown]
# ### Designing Your Own Consistent Heuristic (10 Points)

# %%
s = State()
s.load_puzzle("jams/2.txt")

solution, count = s.solve_graph()
print("number of BFS Optimal Steps: {}, count: {}".format(len(solution), count))
solution, count = s.solve_astar(my_heuristic)
print("number of a* Optimal Steps: {}, count: {}".format(len(solution), count))
# Out:
# number of BFS Optimal Steps: 15, count: 3267
# number of a* Optimal Steps: 15, count: 3268
